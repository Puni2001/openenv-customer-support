# %% [markdown]
# <a href="https://colab.research.google.com/github/Puni2001/frontierops-arena/blob/main/frontierops_training_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FrontierOps Arena — GRPO Training
#
# **OpenEnv Hackathon | Theme #3.1 World Modeling + Theme #1 Multi-Agent**
#
# This notebook trains a compact LLM (`Qwen/Qwen2.5-0.5B-Instruct`) on FrontierOps Arena using GRPO (Group Relative Policy Optimization).
#
# The environment supports both core tracks (`easy`, `medium`, `hard`) and an optional **frontier** track with governance-aware actions and tool evidence collection.
#
# **Reward signal:** Dense shaped rewards based on:
# - Correct categorization / prioritization
# - Resolution quality (knowledge base alignment)
# - SLA compliance
# - Sentiment recovery (empathy detection)
# - VIP customer awareness
# - Governance-safe handoff and evidence-aware behavior (frontier)
#
# > Runtime note: `frontier` fine-tuning/eval is optional in this notebook to keep T4 Colab runs manageable.

# %%
import warnings
import logging
import os
import sys

# 🔧 FIX: Handle TRANSFORMERS_CACHE removal in transformers v4.48+
try:
    import transformers.utils.hub
    if not hasattr(transformers.utils.hub, 'TRANSFORMERS_CACHE'):
        from huggingface_hub.constants import HF_HUB_CACHE
        transformers.utils.hub.TRANSFORMERS_CACHE = HF_HUB_CACHE
except ImportError:
    pass

# Silence all warnings and library chatter
warnings.filterwarnings('ignore')
logging.getLogger('transformers').setLevel(logging.ERROR)
logging.getLogger('trl').setLevel(logging.ERROR)
os.environ['TOKENIZERS_PARALLELISM'] = 'false'
print('✅ Output Silenced: Only critical errors and progress bars will show.')
# Out:
# ✅ Output Silenced: Only critical errors and progress bars will show.

# %%
# 1. Install dependencies
# Suppressing version conflicts that don't affect our project
# !pip install -q -U pydantic click
# !pip install -q openenv "trl>=0.12.0" "transformers<4.48.0" accelerate python-dotenv matplotlib mergekit llm-blender
# !pip install -q "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
print('\n✅ Dependencies installed! Please click "RESTART SESSION" if prompted above.')
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mergekit 0.1.4 requires click==8.2.1, but you have click 8.3.3 which is incompatible.
# mergekit 0.1.4 requires pydantic~=2.10.6, but you have pydantic 2.13.3 which is incompatible.
# gradio 5.50.0 requires pydantic<=2.12.3,>=2.0, but you have pydantic 2.13.3 which is incompatible.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# unsloth-zoo 2026.4.9 requires transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.5.0,>=4.51.3, but you have transformers 4.47.1 which is incompatible.
# unsloth-zoo 2026.4.9 requires trl!=0.19.0,<=0.24.0,>=0.18.2, but you have trl 0.17.0 which is incompatible.
# rasterio 1.5.0 requires click!=8.2.*,>=4.0, but you have click 8.2.1 which is incompatible.
# mcp 1.27.0 requires pydantic<3.0.0,>=2.11.0, but you have pydantic 2.10.6 which is incompatible.
# google-adk 1.29.0 requires pydantic<3.0.0,>=2.12.0, but you have pydantic 2.10.6 which is incompatible.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#
# ✅ Dependencies installed! Please click "RESTART SESSION" if prompted above.

# %%
# Clone the environment repo
# !git clone https://github.com/Puni2001/frontierops-arena.git /content/frontierops-arena
# %cd /content/frontierops-arena
# Out:
# fatal: destination path '/content/frontierops-arena' already exists and is not an empty directory.
# /content/frontierops-arena

# %%
import sys
sys.path.insert(0, '/content/frontierops-arena')

from src.customer_support_env import CustomerSupportEnv, Action, KNOWLEDGE_BASE
from tasks.grader import TaskGrader
print('Environment loaded successfully')
# Out:
# Environment loaded successfully

# %% [markdown]
# ## 1. Baseline Evaluation (Before Training)

# %%
import random

def random_agent_baseline(task_level: str, n_episodes: int = 20):
    """Random agent to establish baseline reward."""
    from src.customer_support_env import TicketCategory, Priority
    env = CustomerSupportEnv(task_level=task_level)
    episode_rewards = []

    for _ in range(n_episodes):
        obs = env.reset()
        total_reward = 0
        while not env.done:
            if task_level == 'easy':
                action = Action(action_type='categorize',
                                value=random.choice([c.value for c in TicketCategory]))
            elif task_level == 'medium':
                action = Action(action_type='prioritize',
                                value=random.choice([p.value for p in Priority]))
            else:
                action = Action(action_type='resolve', value='generic resolution attempt')
            obs, reward, done, _ = env.step(action)
            total_reward += reward
        episode_rewards.append(total_reward)

    return episode_rewards

print('Running random baseline...')
baseline_easy   = random_agent_baseline('easy',   20)
baseline_medium = random_agent_baseline('medium', 20)
baseline_hard   = random_agent_baseline('hard',   20)

print(f'Baseline easy:   avg={sum(baseline_easy)/len(baseline_easy):.4f}')
print(f'Baseline medium: avg={sum(baseline_medium)/len(baseline_medium):.4f}')
print(f'Baseline hard:   avg={sum(baseline_hard)/len(baseline_hard):.4f}')
# Out:
# Running random baseline...
# Baseline easy:   avg=0.0825
# Baseline medium: avg=-0.5600
# Baseline hard:   avg=-0.8675

# %% [markdown]
# ## 2. Generate Training Dataset

# %%
import json

SYSTEM_PROMPTS = {
    'easy':   'You are an enterprise operations triage agent. Classify the ticket into exactly one category: technical, billing, account, feature_request, or complaint. Respond ONLY in JSON: {"action_type": "categorize", "value": "<category>", "reasoning": "<why>"}',
    'medium': 'You are a support ops agent. Set the correct priority: low, medium, high, or urgent. Respond ONLY in JSON: {"action_type": "prioritize", "value": "<priority>", "reasoning": "<why>"}',
    'hard':   'You are a support resolution specialist. Resolve the ticket using KB steps or escalate (if sentiment < -0.7 or category is complaint). Respond ONLY in JSON: {"action_type": "resolve|escalate", "value": "<resolution>", "reasoning": "<why>"}',
    'frontier': 'You are a governance-aware support agent. For high-risk cases collect evidence first via tool_call (policy_lookup, fraud_screen, kyc_verify, trust_safety_review), then choose resolve/escalate/human_review_required/legal_hold. Respond ONLY in JSON: {"action_type": "tool_call|resolve|escalate|human_review_required|legal_hold", "value": "<tool_or_decision>", "reasoning": "<why>"}',
}

def generate_dataset(task_level: str, n: int = 300):
    from src.customer_support_env import CustomerSupportEnv, KNOWLEDGE_BASE
    env = CustomerSupportEnv(task_level=task_level)
    samples = []
    system = SYSTEM_PROMPTS[task_level]
    for _ in range(n):
        obs = env.reset()
        t = obs.current_ticket
        if not t:
            continue

        # No label leakage in prompt.
        meta = [
            f'Ticket: {t.description}',
            f'Sentiment: {t.sentiment:.2f}',
            f'SLA: {obs.current_sla_status}',
            f'VIP: {t.is_vip}',
            f'Previous Contacts: {t.previous_contacts}',
        ]

        if task_level in ('hard', 'frontier'):
            kb = KNOWLEDGE_BASE.get(t.category.value, {})
            meta.append(f'KB Steps: {", ".join(kb.get("steps", []))}')

        if task_level == 'frontier':
            meta.append(f'High Risk Flags: {", ".join(t.high_risk_flags) if t.high_risk_flags else "none"}')
            meta.append(f'Governance Hint: {obs.governance_hint}')

        user = '\n'.join(meta)

        # Store GROUND TRUTH in payload for reward function.
        payload = {
            'category': t.category.value,
            'sentiment': t.sentiment,
            'priority': t.priority.value,
            'is_vip': t.is_vip,
            'previous_contacts': t.previous_contacts,
        }

        samples.append({
            'prompt': [{'role': 'system', 'content': system}, {'role': 'user', 'content': user}],
            'ticket_payload': json.dumps(payload),
        })
    return samples

# Fast-track sample counts for T4 runtime.
train_easy = generate_dataset('easy', 100)
train_medium = generate_dataset('medium', 150)
train_hard = generate_dataset('hard', 200)
ENABLE_FRONTIER = False  # switch to True for optional frontier fine-tuning
train_frontier = generate_dataset('frontier', 120) if ENABLE_FRONTIER else []

print(
    f'✅ Datasets ready: easy={len(train_easy)}, medium={len(train_medium)}, '
    f'hard={len(train_hard)}, frontier={len(train_frontier)} (enabled={ENABLE_FRONTIER})'
)
# Out:
# ✅ Datasets ready: easy=100, medium=150, hard=200, frontier=0 (enabled=False)

# %% [markdown]
# ## 3. Reward Functions

# %%
import re
import json
from datetime import datetime, timedelta
from src.customer_support_env import CustomerSupportEnv, Action, Ticket, TicketCategory, Priority

def make_reward_fn(task_level):
    def reward_fn(completions, prompts=None, **kwargs):
        rewards = []
        ticket_payloads = kwargs.get('ticket_payload', [])

        for i, completion in enumerate(completions):
            try:
                # 1. Extract completion text
                if isinstance(completion, list) and len(completion) > 0:
                    text = completion[0].get('content', str(completion))
                else:
                    text = str(completion)

                # 2. Extract JSON action
                data = {}
                s, e = text.find('{'), text.rfind('}') + 1
                if s != -1:
                    data = json.loads(text[s:e])

                action = Action(
                    action_type=data.get('action_type', 'categorize'),
                    value=str(data.get('value', '')),
                    reasoning=str(data.get('reasoning', ''))
                )

                # 3. Get GROUND TRUTH from payload (REWARD-CONTEXT COUPLING FIX)
                payload = json.loads(ticket_payloads[i]) if i < len(ticket_payloads) else {}

                ticket = Ticket(
                    customer_id="RL_USER",
                    category=TicketCategory(payload.get('category', 'technical')),
                    description="Validation Ticket",
                    sentiment=float(payload.get('sentiment', 0.0)),
                    priority=Priority(payload.get('priority', 'medium')),
                    is_vip=bool(payload.get('is_vip', False)),
                    previous_contacts=int(payload.get('previous_contacts', 0)),
                    sla_deadline=datetime.now() + timedelta(hours=2)
                )

                # 4. Score using environment logic with TRUE ticket
                env = CustomerSupportEnv(task_level=task_level)
                reward_val, _ = env._calculate_reward(action, ticket)
                rewards.append(float(reward_val))

            except Exception as e:
                rewards.append(-0.5) # Penalty for failure
        return rewards
    return reward_fn

# %% [markdown]
# ## 4. GRPO Training with Curriculum

# %%
from unsloth import FastLanguageModel
import torch
from trl import GRPOTrainer, GRPOConfig

MODEL_ID = 'Qwen/Qwen2.5-0.5B-Instruct'
print(f'Loading {MODEL_ID} with Unsloth...')

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=MODEL_ID,
    max_seq_length=2048,
    dtype=None,
    load_in_4bit=True,
    return_dict=True,
)

# SAFETY FIX: Move these outside the parenthesis
tokenizer.pad_token = tokenizer.eos_token
model.config.pad_token_id = tokenizer.eos_token_id

model = FastLanguageModel.get_peft_model(
    model,
    r=16,
    target_modules=['q_proj', 'k_proj', 'v_proj', 'o_proj', 'gate_proj', 'up_proj', 'down_proj'],
    lora_alpha=16,
    use_gradient_checkpointing='unsloth',
)

print('Model loaded safely')
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Loading Qwen/Qwen2.5-0.5B-Instruct with Unsloth...
# ==((====))==  Unsloth 2026.4.8: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/538M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/270 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# unsloth/qwen2.5-0.5b-instruct-unsloth-bnb-4bit does not have a padding token! Will use pad_token = <|PAD_TOKEN|>.
# Model loaded safely

# %%
training_log = []  # for reward curves

curriculum = [('easy', train_easy), ('medium', train_medium), ('hard', train_hard)]
if ENABLE_FRONTIER:
    curriculum.append(('frontier', train_frontier))

for task_level, dataset in curriculum:
    print(f'\n=== Training: {task_level} ===')

    config = GRPOConfig(
        output_dir=f'./checkpoints/{task_level}',
        fp16=not torch.cuda.is_bf16_supported(),
        bf16=torch.cuda.is_bf16_supported(),
        num_train_epochs=2,
        per_device_train_batch_size=2,
        gradient_accumulation_steps=4,
        learning_rate=5e-6,
        max_completion_length=200,
        num_generations=4,
        temperature=0.8,
        logging_steps=5,
        save_steps=50,
        report_to='none',
    )

    # 1. Define the callback
    from transformers import TrainerCallback
    class LiveMonitorCallback(TrainerCallback):
        def on_step_end(self, args, state, control, **kwargs):
            if state.global_step % 50 == 0 and state.global_step > 0:
                print(f"\n🚀 STEP {state.global_step}: THE AGENT IS THINKING...")
                model.eval()
                test_sample = dataset[0]['prompt']
                inputs = tokenizer.apply_chat_template(test_sample, return_tensors="pt", add_generation_prompt=True).to("cuda")
                with torch.no_grad():
                    outputs = model.generate(inputs, max_new_tokens=100)
                    print(tokenizer.decode(outputs[0], skip_special_tokens=True).split('assistant')[-1])
                model.train()

    # 2. Aggressive patch to fix the 'set' vs 'dict' error
    for m in [model, getattr(model, 'base_model', None), getattr(getattr(model, 'base_model', None), 'model', None)]:
        if m is not None: object.__setattr__(m, 'warnings_issued', {})

    # 3. Create the trainer with keyword arguments only
    trainer = GRPOTrainer(
        model=model,
        processing_class=tokenizer,
        reward_funcs=make_reward_fn(task_level),
        args=config,
        train_dataset=dataset,
        callbacks=[LiveMonitorCallback()]
    )

    result = trainer.train()
    training_log.append({'task': task_level, 'log_history': trainer.state.log_history})
    print(f'Done: {task_level}')
# Out:
# === Training: easy ===
# Unsloth: Will smartly offload gradients to save VRAM!
# {'loss': '-0.04253', 'grad_norm': '1.145', 'learning_rate': '2e-06', 'num_tokens': '7859', 'completions/mean_length': '76.47', 'completions/min_length': '42.2', 'completions/max_length': '112', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '76.47', 'completions/min_terminated_length': '42.2', 'completions/max_terminated_length': '112', 'rewards/reward_fn/mean': '0.07675', 'rewards/reward_fn/std': '0.1328', 'reward': '0.07675', 'reward_std': '0.0965', 'frac_reward_zero_std': '0.7', 'completion_length': '75.47', 'kl': '5.294e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.1'}
# {'loss': '-0.01572', 'grad_norm': '0.8213', 'learning_rate': '4.5e-06', 'num_tokens': '1.561e+04', 'completions/mean_length': '74.47', 'completions/min_length': '40.6', 'completions/max_length': '122.4', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '74.47', 'completions/min_terminated_length': '40.6', 'completions/max_terminated_length': '122.4', 'rewards/reward_fn/mean': '0.06925', 'rewards/reward_fn/std': '0.09318', 'reward': '0.06925', 'reward_std': '0.0765', 'frac_reward_zero_std': '0.7', 'completion_length': '73.47', 'kl': '4.696e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.2'}
# {'loss': '0.02461', 'grad_norm': '0.0002109', 'learning_rate': '4.778e-06', 'num_tokens': '2.328e+04', 'completions/mean_length': '73.5', 'completions/min_length': '48.4', 'completions/max_length': '118.8', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '73.5', 'completions/min_terminated_length': '48.4', 'completions/max_terminated_length': '118.8', 'rewards/reward_fn/mean': '0.06325', 'rewards/reward_fn/std': '0.1596', 'reward': '0.06325', 'reward_std': '0.1235', 'frac_reward_zero_std': '0.5', 'completion_length': '72.5', 'kl': '0.000151', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.3'}
# {'loss': '0.01367', 'grad_norm': '0.72', 'learning_rate': '4.5e-06', 'num_tokens': '3.112e+04', 'completions/mean_length': '75.58', 'completions/min_length': '47.4', 'completions/max_length': '133.4', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '72.2', 'completions/min_terminated_length': '47.4', 'completions/max_terminated_length': '110.6', 'rewards/reward_fn/mean': '0.084', 'rewards/reward_fn/std': '0.06647', 'reward': '0.084', 'reward_std': '0.047', 'frac_reward_zero_std': '0.8', 'completion_length': '74.6', 'kl': '0.0005352', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.4'}
# {'loss': '0.01551', 'grad_norm': '0.0001933', 'learning_rate': '4.222e-06', 'num_tokens': '3.913e+04', 'completions/mean_length': '82.4', 'completions/min_length': '48', 'completions/max_length': '130.8', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '82.4', 'completions/min_terminated_length': '48', 'completions/max_terminated_length': '130.8', 'rewards/reward_fn/mean': '0.09275', 'rewards/reward_fn/std': '0.09122', 'reward': '0.09275', 'reward_std': '0.0645', 'frac_reward_zero_std': '0.7', 'completion_length': '81.4', 'kl': '0.0009441', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.5'}
# {'loss': '0.02911', 'grad_norm': '0.7782', 'learning_rate': '3.944e-06', 'num_tokens': '4.652e+04', 'completions/mean_length': '67.12', 'completions/min_length': '43', 'completions/max_length': '101', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '67.12', 'completions/min_terminated_length': '43', 'completions/max_terminated_length': '101', 'rewards/reward_fn/mean': '0.06525', 'rewards/reward_fn/std': '0.07', 'reward': '0.06525', 'reward_std': '0.0495', 'frac_reward_zero_std': '0.8', 'completion_length': '66.12', 'kl': '0.001536', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.6'}
# {'loss': '-0.04426', 'grad_norm': '0.7282', 'learning_rate': '3.667e-06', 'num_tokens': '5.414e+04', 'completions/mean_length': '70.92', 'completions/min_length': '46.6', 'completions/max_length': '118', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '70.92', 'completions/min_terminated_length': '46.6', 'completions/max_terminated_length': '118', 'rewards/reward_fn/mean': '0.1217', 'rewards/reward_fn/std': '0.1801', 'reward': '0.1217', 'reward_std': '0.1465', 'frac_reward_zero_std': '0.3', 'completion_length': '69.92', 'kl': '0.002246', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.7'}
# {'loss': '0.007271', 'grad_norm': '1.325', 'learning_rate': '3.389e-06', 'num_tokens': '6.182e+04', 'completions/mean_length': '72.5', 'completions/min_length': '43', 'completions/max_length': '121.8', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '72.5', 'completions/min_terminated_length': '43', 'completions/max_terminated_length': '121.8', 'rewards/reward_fn/mean': '0.0955', 'rewards/reward_fn/std': '0.1674', 'reward': '0.0955', 'reward_std': '0.129', 'frac_reward_zero_std': '0.4', 'completion_length': '71.5', 'kl': '0.005463', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.8'}
# {'loss': '-0.006517', 'grad_norm': '1.105', 'learning_rate': '3.111e-06', 'num_tokens': '6.928e+04', 'completions/mean_length': '67.95', 'completions/min_length': '42.2', 'completions/max_length': '98.4', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '67.95', 'completions/min_terminated_length': '42.2', 'completions/max_terminated_length': '98.4', 'rewards/reward_fn/mean': '0.1157', 'rewards/reward_fn/std': '0.2165', 'reward': '0.1157', 'reward_std': '0.1935', 'frac_reward_zero_std': '0.1', 'completion_length': '66.95', 'kl': '0.004688', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.9'}
#
# 🚀 STEP 50: THE AGENT IS THINKING...
#
# {"action_type": "categorize", "value": "feature_request", "reasoning": "The customer is seeking a feature to address a perceived issue with currency conversion rates, indicating it falls under feature requests."}
# {'loss': '-0.03019', 'grad_norm': '0.8066', 'learning_rate': '2.833e-06', 'num_tokens': '7.67e+04', 'completions/mean_length': '66.97', 'completions/min_length': '50.2', 'completions/max_length': '93.6', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '66.97', 'completions/min_terminated_length': '50.2', 'completions/max_terminated_length': '93.6', 'rewards/reward_fn/mean': '0.1015', 'rewards/reward_fn/std': '0.09887', 'reward': '0.1015', 'reward_std': '0.06721', 'frac_reward_zero_std': '0.7', 'completion_length': '65.97', 'kl': '0.003819', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1'}
# {'loss': '0.01687', 'grad_norm': '0.0005148', 'learning_rate': '2.556e-06', 'num_tokens': '8.433e+04', 'completions/mean_length': '71.47', 'completions/min_length': '43', 'completions/max_length': '113.2', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '71.47', 'completions/min_terminated_length': '43', 'completions/max_terminated_length': '113.2', 'rewards/reward_fn/mean': '0.1512', 'rewards/reward_fn/std': '0.09457', 'reward': '0.1512', 'reward_std': '0.0525', 'frac_reward_zero_std': '0.7', 'completion_length': '70.47', 'kl': '0.006037', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.1'}
# {'loss': '0.02327', 'grad_norm': '0.9125', 'learning_rate': '2.278e-06', 'num_tokens': '9.205e+04', 'completions/mean_length': '72.9', 'completions/min_length': '47.4', 'completions/max_length': '123.6', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '69.88', 'completions/min_terminated_length': '47.4', 'completions/max_terminated_length': '107', 'rewards/reward_fn/mean': '0.1217', 'rewards/reward_fn/std': '0.1496', 'reward': '0.1217', 'reward_std': '0.1386', 'frac_reward_zero_std': '0.5', 'completion_length': '71.92', 'kl': '0.008386', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.2'}
# {'loss': '-0.02783', 'grad_norm': '1.126', 'learning_rate': '2e-06', 'num_tokens': '9.938e+04', 'completions/mean_length': '64.03', 'completions/min_length': '41.2', 'completions/max_length': '103', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '64.03', 'completions/min_terminated_length': '41.2', 'completions/max_terminated_length': '103', 'rewards/reward_fn/mean': '0.1117', 'rewards/reward_fn/std': '0.1745', 'reward': '0.1117', 'reward_std': '0.1318', 'frac_reward_zero_std': '0.4', 'completion_length': '63.02', 'kl': '0.009533', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.3'}
# {'loss': '-0.03378', 'grad_norm': '0.8854', 'learning_rate': '1.722e-06', 'num_tokens': '1.07e+05', 'completions/mean_length': '69.58', 'completions/min_length': '43.2', 'completions/max_length': '94.6', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '69.58', 'completions/min_terminated_length': '43.2', 'completions/max_terminated_length': '94.6', 'rewards/reward_fn/mean': '0.2212', 'rewards/reward_fn/std': '0.1555', 'reward': '0.2212', 'reward_std': '0.1077', 'frac_reward_zero_std': '0.4', 'completion_length': '68.58', 'kl': '0.01182', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.4'}
# {'loss': '-0.0007816', 'grad_norm': '0.9204', 'learning_rate': '1.444e-06', 'num_tokens': '1.143e+05', 'completions/mean_length': '64.75', 'completions/min_length': '42', 'completions/max_length': '104.4', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '64.75', 'completions/min_terminated_length': '42', 'completions/max_terminated_length': '104.4', 'rewards/reward_fn/mean': '0.1527', 'rewards/reward_fn/std': '0.1916', 'reward': '0.1527', 'reward_std': '0.1679', 'frac_reward_zero_std': '0.3', 'completion_length': '63.75', 'kl': '0.01411', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.5'}
# {'loss': '0.01507', 'grad_norm': '0.8544', 'learning_rate': '1.167e-06', 'num_tokens': '1.216e+05', 'completions/mean_length': '64.22', 'completions/min_length': '42', 'completions/max_length': '90', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '64.22', 'completions/min_terminated_length': '42', 'completions/max_terminated_length': '90', 'rewards/reward_fn/mean': '0.1817', 'rewards/reward_fn/std': '0.183', 'reward': '0.1817', 'reward_std': '0.1485', 'frac_reward_zero_std': '0.4', 'completion_length': '63.23', 'kl': '0.01816', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.6'}
# {'loss': '-0.004412', 'grad_norm': '0.0009565', 'learning_rate': '8.889e-07', 'num_tokens': '1.292e+05', 'completions/mean_length': '72.95', 'completions/min_length': '45.4', 'completions/max_length': '99', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '72.95', 'completions/min_terminated_length': '45.4', 'completions/max_terminated_length': '99', 'rewards/reward_fn/mean': '0.1615', 'rewards/reward_fn/std': '0.1677', 'reward': '0.1615', 'reward_std': '0.1074', 'frac_reward_zero_std': '0.5', 'completion_length': '71.95', 'kl': '0.01917', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.7'}
# {'loss': '-0.06785', 'grad_norm': '0.7426', 'learning_rate': '6.111e-07', 'num_tokens': '1.369e+05', 'completions/mean_length': '72.75', 'completions/min_length': '41.8', 'completions/max_length': '116.2', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '72.75', 'completions/min_terminated_length': '41.8', 'completions/max_terminated_length': '116.2', 'rewards/reward_fn/mean': '0.1352', 'rewards/reward_fn/std': '0.155', 'reward': '0.1352', 'reward_std': '0.1195', 'frac_reward_zero_std': '0.5', 'completion_length': '71.75', 'kl': '0.02497', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.8'}
# {'loss': '0.006618', 'grad_norm': '1.153', 'learning_rate': '3.333e-07', 'num_tokens': '1.445e+05', 'completions/mean_length': '71.62', 'completions/min_length': '44.2', 'completions/max_length': '103', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '71.62', 'completions/min_terminated_length': '44.2', 'completions/max_terminated_length': '103', 'rewards/reward_fn/mean': '0.1965', 'rewards/reward_fn/std': '0.2046', 'reward': '0.1965', 'reward_std': '0.1572', 'frac_reward_zero_std': '0.2', 'completion_length': '70.62', 'kl': '0.01671', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.9'}
#
# 🚀 STEP 100: THE AGENT IS THINKING...
#
# {"action_type": "categorize", "value": "technical", "reasoning": "The customer is reporting a technical issue with the currency conversion rate and wants assistance to resolve it. They have not reached the SLA (Service Level Agreement) or VIP (Very Important) level of support."}
# {'loss': '-0.003065', 'grad_norm': '0.9502', 'learning_rate': '5.556e-08', 'num_tokens': '1.524e+05', 'completions/mean_length': '78.3', 'completions/min_length': '45.4', 'completions/max_length': '128.2', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '78.3', 'completions/min_terminated_length': '45.4', 'completions/max_terminated_length': '128.2', 'rewards/reward_fn/mean': '0.1905', 'rewards/reward_fn/std': '0.1738', 'reward': '0.1905', 'reward_std': '0.1413', 'frac_reward_zero_std': '0.4', 'completion_length': '77.3', 'kl': '0.02116', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '2'}
# {'train_runtime': '1319', 'train_samples_per_second': '0.152', 'train_steps_per_second': '0.076', 'train_loss': '-0.006247', 'epoch': '2'}
# Done: easy
#
# === Training: medium ===
# Unsloth: Will smartly offload gradients to save VRAM!
# {'loss': '0.01475', 'grad_norm': '0.9534', 'learning_rate': '1.333e-06', 'num_tokens': '7580', 'completions/mean_length': '82', 'completions/min_length': '43.8', 'completions/max_length': '120.6', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '82', 'completions/min_terminated_length': '43.8', 'completions/max_terminated_length': '120.6', 'rewards/reward_fn/mean': '0.076', 'rewards/reward_fn/std': '0.331', 'reward': '0.076', 'reward_std': '0.2827', 'frac_reward_zero_std': '0.1', 'completion_length': '81', 'kl': '0.002503', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.06667'}
# {'loss': '0.04701', 'grad_norm': '0.9279', 'learning_rate': '3e-06', 'num_tokens': '1.5e+04', 'completions/mean_length': '78.72', 'completions/min_length': '49', 'completions/max_length': '137.8', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '75.26', 'completions/min_terminated_length': '49', 'completions/max_terminated_length': '115.6', 'rewards/reward_fn/mean': '0.06475', 'rewards/reward_fn/std': '0.3336', 'reward': '0.06475', 'reward_std': '0.298', 'frac_reward_zero_std': '0.1', 'completion_length': '77.75', 'kl': '0.002864', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.1333'}
# {'loss': '0.04106', 'grad_norm': '0.9636', 'learning_rate': '4.667e-06', 'num_tokens': '2.284e+04', 'completions/mean_length': '87.25', 'completions/min_length': '49.2', 'completions/max_length': '153.6', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '87.25', 'completions/min_terminated_length': '49.2', 'completions/max_terminated_length': '153.6', 'rewards/reward_fn/mean': '0.116', 'rewards/reward_fn/std': '0.2906', 'reward': '0.116', 'reward_std': '0.2974', 'frac_reward_zero_std': '0', 'completion_length': '86.25', 'kl': '0.002711', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.2'}
# {'loss': '0.05893', 'grad_norm': '0.8579', 'learning_rate': '4.852e-06', 'num_tokens': '3.053e+04', 'completions/mean_length': '84.08', 'completions/min_length': '53.8', 'completions/max_length': '157.6', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '81.29', 'completions/min_terminated_length': '53.8', 'completions/max_terminated_length': '141.8', 'rewards/reward_fn/mean': '0.0535', 'rewards/reward_fn/std': '0.2951', 'reward': '0.0535', 'reward_std': '0.2503', 'frac_reward_zero_std': '0.3', 'completion_length': '83.1', 'kl': '0.004022', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.2667'}
# {'loss': '0.02188', 'grad_norm': '0.0003945', 'learning_rate': '4.667e-06', 'num_tokens': '3.815e+04', 'completions/mean_length': '82.1', 'completions/min_length': '58.2', 'completions/max_length': '122.4', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '82.1', 'completions/min_terminated_length': '58.2', 'completions/max_terminated_length': '122.4', 'rewards/reward_fn/mean': '0.03925', 'rewards/reward_fn/std': '0.2645', 'reward': '0.03925', 'reward_std': '0.1742', 'frac_reward_zero_std': '0.5', 'completion_length': '81.1', 'kl': '0.004151', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.3333'}
# {'loss': '0.06363', 'grad_norm': '0.8683', 'learning_rate': '4.481e-06', 'num_tokens': '4.561e+04', 'completions/mean_length': '78.2', 'completions/min_length': '51.2', 'completions/max_length': '119', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '78.2', 'completions/min_terminated_length': '51.2', 'completions/max_terminated_length': '119', 'rewards/reward_fn/mean': '0.1455', 'rewards/reward_fn/std': '0.2448', 'reward': '0.1455', 'reward_std': '0.2032', 'frac_reward_zero_std': '0.2', 'completion_length': '77.2', 'kl': '0.005539', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.4'}
# {'loss': '0.02044', 'grad_norm': '0.7562', 'learning_rate': '4.296e-06', 'num_tokens': '5.326e+04', 'completions/mean_length': '82.75', 'completions/min_length': '42.6', 'completions/max_length': '139', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '79.86', 'completions/min_terminated_length': '42.6', 'completions/max_terminated_length': '128.4', 'rewards/reward_fn/mean': '0.0215', 'rewards/reward_fn/std': '0.2757', 'reward': '0.0215', 'reward_std': '0.129', 'frac_reward_zero_std': '0.6', 'completion_length': '81.78', 'kl': '0.01255', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.4667'}
# {'loss': '-0.006814', 'grad_norm': '0.653', 'learning_rate': '4.111e-06', 'num_tokens': '6.081e+04', 'completions/mean_length': '80.45', 'completions/min_length': '51.8', 'completions/max_length': '126.8', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '80.45', 'completions/min_terminated_length': '51.8', 'completions/max_terminated_length': '126.8', 'rewards/reward_fn/mean': '0.1388', 'rewards/reward_fn/std': '0.2439', 'reward': '0.1388', 'reward_std': '0.1305', 'frac_reward_zero_std': '0.5', 'completion_length': '79.45', 'kl': '0.00685', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.5333'}
# {'loss': '0.03091', 'grad_norm': '1.063', 'learning_rate': '3.926e-06', 'num_tokens': '6.81e+04', 'completions/mean_length': '73.88', 'completions/min_length': '47', 'completions/max_length': '116.4', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '73.88', 'completions/min_terminated_length': '47', 'completions/max_terminated_length': '116.4', 'rewards/reward_fn/mean': '0.1278', 'rewards/reward_fn/std': '0.2136', 'reward': '0.1277', 'reward_std': '0.1705', 'frac_reward_zero_std': '0.3', 'completion_length': '72.88', 'kl': '0.009271', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.6'}
#
# 🚀 STEP 50: THE AGENT IS THINKING...
#
# {"action_type": "prioritize", "value": "high", "reasoning": "Customer's complaint is about the delayed refund process and unresolved issues with the order status, which could indicate an issue with the system's ability to handle refunds quickly. The customer's satisfaction level (0.06) suggests that this problem might warrant attention."}
# {'loss': '0.02367', 'grad_norm': '0.6886', 'learning_rate': '3.741e-06', 'num_tokens': '7.55e+04', 'completions/mean_length': '76.7', 'completions/min_length': '55.4', 'completions/max_length': '114.8', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '76.7', 'completions/min_terminated_length': '55.4', 'completions/max_terminated_length': '114.8', 'rewards/reward_fn/mean': '0.2153', 'rewards/reward_fn/std': '0.2162', 'reward': '0.2153', 'reward_std': '0.132', 'frac_reward_zero_std': '0.5', 'completion_length': '75.7', 'kl': '0.007921', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.6667'}
# {'loss': '0.02772', 'grad_norm': '0.001037', 'learning_rate': '3.556e-06', 'num_tokens': '8.276e+04', 'completions/mean_length': '72.92', 'completions/min_length': '42.2', 'completions/max_length': '137.8', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '69.45', 'completions/min_terminated_length': '42.2', 'completions/max_terminated_length': '119.2', 'rewards/reward_fn/mean': '0.08075', 'rewards/reward_fn/std': '0.2463', 'reward': '0.08075', 'reward_std': '0.1755', 'frac_reward_zero_std': '0.5', 'completion_length': '71.95', 'kl': '0.02285', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.7333'}
# {'loss': '0.007868', 'grad_norm': '0.8161', 'learning_rate': '3.37e-06', 'num_tokens': '9.005e+04', 'completions/mean_length': '73.58', 'completions/min_length': '47.8', 'completions/max_length': '104.8', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '73.58', 'completions/min_terminated_length': '47.8', 'completions/max_terminated_length': '104.8', 'rewards/reward_fn/mean': '0.1955', 'rewards/reward_fn/std': '0.1393', 'reward': '0.1955', 'reward_std': '0.084', 'frac_reward_zero_std': '0.7', 'completion_length': '72.58', 'kl': '0.008046', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.8'}
# {'loss': '-0.02414', 'grad_norm': '0.0007153', 'learning_rate': '3.185e-06', 'num_tokens': '9.708e+04', 'completions/mean_length': '67.88', 'completions/min_length': '37.2', 'completions/max_length': '103.6', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '67.88', 'completions/min_terminated_length': '37.2', 'completions/max_terminated_length': '103.6', 'rewards/reward_fn/mean': '0.2025', 'rewards/reward_fn/std': '0.1344', 'reward': '0.2025', 'reward_std': '0.065', 'frac_reward_zero_std': '0.8', 'completion_length': '66.88', 'kl': '0.02553', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.8667'}
# {'loss': '0.01355', 'grad_norm': '0.001146', 'learning_rate': '3e-06', 'num_tokens': '1.044e+05', 'completions/mean_length': '74.8', 'completions/min_length': '48.2', 'completions/max_length': '102', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '74.8', 'completions/min_terminated_length': '48.2', 'completions/max_terminated_length': '102', 'rewards/reward_fn/mean': '0.2378', 'rewards/reward_fn/std': '0.1789', 'reward': '0.2378', 'reward_std': '0.0745', 'frac_reward_zero_std': '0.8', 'completion_length': '73.8', 'kl': '0.009981', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.9333'}
# {'loss': '0.01049', 'grad_norm': '0.5959', 'learning_rate': '2.815e-06', 'num_tokens': '1.118e+05', 'completions/mean_length': '76.47', 'completions/min_length': '52.6', 'completions/max_length': '104.4', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '76.47', 'completions/min_terminated_length': '52.6', 'completions/max_terminated_length': '104.4', 'rewards/reward_fn/mean': '0.208', 'rewards/reward_fn/std': '0.2022', 'reward': '0.208', 'reward_std': '0.1031', 'frac_reward_zero_std': '0.6', 'completion_length': '75.47', 'kl': '0.01305', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1'}
# {'loss': '-0.03181', 'grad_norm': '1.234', 'learning_rate': '2.63e-06', 'num_tokens': '1.188e+05', 'completions/mean_length': '66.65', 'completions/min_length': '44.2', 'completions/max_length': '97.2', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '66.65', 'completions/min_terminated_length': '44.2', 'completions/max_terminated_length': '97.2', 'rewards/reward_fn/mean': '0.2217', 'rewards/reward_fn/std': '0.2407', 'reward': '0.2217', 'reward_std': '0.1765', 'frac_reward_zero_std': '0.4', 'completion_length': '65.65', 'kl': '0.04144', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.067'}
# {'loss': '0.00117', 'grad_norm': '0.6416', 'learning_rate': '2.444e-06', 'num_tokens': '1.258e+05', 'completions/mean_length': '68.03', 'completions/min_length': '41.4', 'completions/max_length': '106.2', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '68.03', 'completions/min_terminated_length': '41.4', 'completions/max_terminated_length': '106.2', 'rewards/reward_fn/mean': '0.2537', 'rewards/reward_fn/std': '0.1661', 'reward': '0.2537', 'reward_std': '0.0625', 'frac_reward_zero_std': '0.7', 'completion_length': '67.03', 'kl': '0.01367', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.133'}
# {'loss': '-0.0143', 'grad_norm': '0.6931', 'learning_rate': '2.259e-06', 'num_tokens': '1.329e+05', 'completions/mean_length': '69.72', 'completions/min_length': '44.8', 'completions/max_length': '108.4', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '69.72', 'completions/min_terminated_length': '44.8', 'completions/max_terminated_length': '108.4', 'rewards/reward_fn/mean': '0.1443', 'rewards/reward_fn/std': '0.1887', 'reward': '0.1443', 'reward_std': '0.1165', 'frac_reward_zero_std': '0.6', 'completion_length': '68.72', 'kl': '0.015', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.2'}
# {'loss': '0.04215', 'grad_norm': '0.8329', 'learning_rate': '2.074e-06', 'num_tokens': '1.407e+05', 'completions/mean_length': '85.47', 'completions/min_length': '53', 'completions/max_length': '141.6', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '82.7', 'completions/min_terminated_length': '53', 'completions/max_terminated_length': '126.4', 'rewards/reward_fn/mean': '0.1432', 'rewards/reward_fn/std': '0.2992', 'reward': '0.1433', 'reward_std': '0.2033', 'frac_reward_zero_std': '0.4', 'completion_length': '84.5', 'kl': '0.01643', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.267'}
#
# 🚀 STEP 100: THE AGENT IS THINKING...
#
# {"action_type": "prioritize", "value": "high", "reasoning": "The customer's issue of receiving their order after cancelation has been unresolved for 14 days, which falls under the 'High' SLA (Service Level Agreement) and is considered an overdue complaint. The ticket was sent by a Support Ops agent who handled it promptly but still needs to be reviewed by a higher-level support personnel due to its urgency."}
# {'loss': '0.01731', 'grad_norm': '0.6731', 'learning_rate': '1.889e-06', 'num_tokens': '1.481e+05', 'completions/mean_length': '76.33', 'completions/min_length': '53', 'completions/max_length': '111.2', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '76.33', 'completions/min_terminated_length': '53', 'completions/max_terminated_length': '111.2', 'rewards/reward_fn/mean': '0.292', 'rewards/reward_fn/std': '0.1502', 'reward': '0.292', 'reward_std': '0.0905', 'frac_reward_zero_std': '0.8', 'completion_length': '75.33', 'kl': '0.009807', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.333'}
# {'loss': '0.001117', 'grad_norm': '0.0006792', 'learning_rate': '1.704e-06', 'num_tokens': '1.557e+05', 'completions/mean_length': '80.97', 'completions/min_length': '58', 'completions/max_length': '116.8', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '80.97', 'completions/min_terminated_length': '58', 'completions/max_terminated_length': '116.8', 'rewards/reward_fn/mean': '0.2107', 'rewards/reward_fn/std': '0.2432', 'reward': '0.2107', 'reward_std': '0.1185', 'frac_reward_zero_std': '0.7', 'completion_length': '79.97', 'kl': '0.00815', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.4'}
# {'loss': '0.01111', 'grad_norm': '0.0004792', 'learning_rate': '1.519e-06', 'num_tokens': '1.631e+05', 'completions/mean_length': '76.47', 'completions/min_length': '48.8', 'completions/max_length': '117.8', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '76.47', 'completions/min_terminated_length': '48.8', 'completions/max_terminated_length': '117.8', 'rewards/reward_fn/mean': '0.2842', 'rewards/reward_fn/std': '0.1756', 'reward': '0.2842', 'reward_std': '0.0715', 'frac_reward_zero_std': '0.8', 'completion_length': '75.47', 'kl': '0.01093', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.467'}
# {'loss': '-0.0008592', 'grad_norm': '0.001421', 'learning_rate': '1.333e-06', 'num_tokens': '1.707e+05', 'completions/mean_length': '82.8', 'completions/min_length': '56.8', 'completions/max_length': '124.2', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '82.8', 'completions/min_terminated_length': '56.8', 'completions/max_terminated_length': '124.2', 'rewards/reward_fn/mean': '0.2262', 'rewards/reward_fn/std': '0.1567', 'reward': '0.2262', 'reward_std': '0.0125', 'frac_reward_zero_std': '0.9', 'completion_length': '81.8', 'kl': '0.01368', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.533'}
# {'loss': '0.03135', 'grad_norm': '1.785', 'learning_rate': '1.148e-06', 'num_tokens': '1.782e+05', 'completions/mean_length': '77.88', 'completions/min_length': '45.8', 'completions/max_length': '138.2', 'completions/clipped_ratio': '0.05', 'completions/mean_terminated_length': '71.87', 'completions/min_terminated_length': '45.8', 'completions/max_terminated_length': '108.8', 'rewards/reward_fn/mean': '0.199', 'rewards/reward_fn/std': '0.1857', 'reward': '0.199', 'reward_std': '0.08789', 'frac_reward_zero_std': '0.6', 'completion_length': '76.92', 'kl': '0.02498', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.6'}
# {'loss': '0.03906', 'grad_norm': '0.7037', 'learning_rate': '9.63e-07', 'num_tokens': '1.856e+05', 'completions/mean_length': '77.08', 'completions/min_length': '53.8', 'completions/max_length': '123.2', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '74.08', 'completions/min_terminated_length': '53.8', 'completions/max_terminated_length': '109.8', 'rewards/reward_fn/mean': '0.1068', 'rewards/reward_fn/std': '0.2106', 'reward': '0.1068', 'reward_std': '0.1365', 'frac_reward_zero_std': '0.6', 'completion_length': '76.1', 'kl': '0.01354', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.667'}
# {'loss': '-0.02387', 'grad_norm': '0.0004221', 'learning_rate': '7.778e-07', 'num_tokens': '1.927e+05', 'completions/mean_length': '68.28', 'completions/min_length': '43.4', 'completions/max_length': '107.6', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '68.28', 'completions/min_terminated_length': '43.4', 'completions/max_terminated_length': '107.6', 'rewards/reward_fn/mean': '0.1778', 'rewards/reward_fn/std': '0.1855', 'reward': '0.1778', 'reward_std': '0.0745', 'frac_reward_zero_std': '0.8', 'completion_length': '67.28', 'kl': '0.01203', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.733'}
# {'loss': '0.007869', 'grad_norm': '0.9415', 'learning_rate': '5.926e-07', 'num_tokens': '1.998e+05', 'completions/mean_length': '70.33', 'completions/min_length': '44.4', 'completions/max_length': '96.4', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '70.33', 'completions/min_terminated_length': '44.4', 'completions/max_terminated_length': '96.4', 'rewards/reward_fn/mean': '0.164', 'rewards/reward_fn/std': '0.1316', 'reward': '0.164', 'reward_std': '0.072', 'frac_reward_zero_std': '0.8', 'completion_length': '69.33', 'kl': '0.02', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.8'}
# {'loss': '0.04935', 'grad_norm': '0.0006026', 'learning_rate': '4.074e-07', 'num_tokens': '2.071e+05', 'completions/mean_length': '75.38', 'completions/min_length': '47', 'completions/max_length': '115', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '75.38', 'completions/min_terminated_length': '47', 'completions/max_terminated_length': '115', 'rewards/reward_fn/mean': '0.2607', 'rewards/reward_fn/std': '0.1949', 'reward': '0.2607', 'reward_std': '0.1435', 'frac_reward_zero_std': '0.6', 'completion_length': '74.38', 'kl': '0.01549', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.867'}
# {'loss': '-0.002495', 'grad_norm': '0.6421', 'learning_rate': '2.222e-07', 'num_tokens': '2.146e+05', 'completions/mean_length': '76.83', 'completions/min_length': '53.4', 'completions/max_length': '105.6', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '76.83', 'completions/min_terminated_length': '53.4', 'completions/max_terminated_length': '105.6', 'rewards/reward_fn/mean': '0.108', 'rewards/reward_fn/std': '0.2342', 'reward': '0.108', 'reward_std': '0.1775', 'frac_reward_zero_std': '0.5', 'completion_length': '75.83', 'kl': '0.02421', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.933'}
#
# 🚀 STEP 150: THE AGENT IS THINKING...
#
# {"action_type": "prioritize", "value": "high", "reasoning": "The customer has been waiting for a refund despite having canceled their order and experiencing issues with tracking and service delivery."}
# {'loss': '0.04249', 'grad_norm': '0.9438', 'learning_rate': '3.704e-08', 'num_tokens': '2.219e+05', 'completions/mean_length': '75.85', 'completions/min_length': '52.8', 'completions/max_length': '120.8', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '72.82', 'completions/min_terminated_length': '52.8', 'completions/max_terminated_length': '106.6', 'rewards/reward_fn/mean': '0.1627', 'rewards/reward_fn/std': '0.1271', 'reward': '0.1627', 'reward_std': '0.0745', 'frac_reward_zero_std': '0.7', 'completion_length': '74.88', 'kl': '0.01366', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '2'}
# {'train_runtime': '1681', 'train_samples_per_second': '0.178', 'train_steps_per_second': '0.089', 'train_loss': '0.01735', 'epoch': '2'}
# Done: medium
#
# === Training: hard ===
# Unsloth: Will smartly offload gradients to save VRAM!
# {'loss': '0.04794', 'grad_norm': '0.5669', 'learning_rate': '1e-06', 'num_tokens': '9051', 'completions/mean_length': '89.58', 'completions/min_length': '51.2', 'completions/max_length': '145.6', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '86.62', 'completions/min_terminated_length': '51.2', 'completions/max_terminated_length': '135.6', 'rewards/reward_fn/mean': '0.2019', 'rewards/reward_fn/std': '0.3125', 'reward': '0.2019', 'reward_std': '0.1952', 'frac_reward_zero_std': '0.3', 'completion_length': '88.6', 'kl': '0.004829', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.05'}
# {'loss': '0.01348', 'grad_norm': '1.1', 'learning_rate': '2.25e-06', 'num_tokens': '1.845e+04', 'completions/mean_length': '96.88', 'completions/min_length': '53.2', 'completions/max_length': '168.2', 'completions/clipped_ratio': '0.05', 'completions/mean_terminated_length': '91.84', 'completions/min_terminated_length': '53.2', 'completions/max_terminated_length': '149.2', 'rewards/reward_fn/mean': '0.2345', 'rewards/reward_fn/std': '0.2142', 'reward': '0.2345', 'reward_std': '0.1321', 'frac_reward_zero_std': '0.5', 'completion_length': '95.92', 'kl': '0.005123', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.1'}
# {'loss': '0.005723', 'grad_norm': '0.0026', 'learning_rate': '3.5e-06', 'num_tokens': '2.746e+04', 'completions/mean_length': '88.67', 'completions/min_length': '51.4', 'completions/max_length': '155', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '88.67', 'completions/min_terminated_length': '51.4', 'completions/max_terminated_length': '155', 'rewards/reward_fn/mean': '0.1782', 'rewards/reward_fn/std': '0.2326', 'reward': '0.1782', 'reward_std': '0.08909', 'frac_reward_zero_std': '0.7', 'completion_length': '87.67', 'kl': '0.005194', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.15'}
# {'loss': '0.02881', 'grad_norm': '1.316', 'learning_rate': '4.75e-06', 'num_tokens': '3.648e+04', 'completions/mean_length': '89.17', 'completions/min_length': '57.6', 'completions/max_length': '138.4', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '86.44', 'completions/min_terminated_length': '57.6', 'completions/max_terminated_length': '123.4', 'rewards/reward_fn/mean': '0.2242', 'rewards/reward_fn/std': '0.3126', 'reward': '0.2242', 'reward_std': '0.1887', 'frac_reward_zero_std': '0.4', 'completion_length': '88.2', 'kl': '0.005579', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.2'}
# {'loss': '0.0001796', 'grad_norm': '0.6901', 'learning_rate': '4.889e-06', 'num_tokens': '4.562e+04', 'completions/mean_length': '92.6', 'completions/min_length': '59.6', 'completions/max_length': '156.2', 'completions/clipped_ratio': '0.05', 'completions/mean_terminated_length': '86.59', 'completions/min_terminated_length': '59.6', 'completions/max_terminated_length': '128.8', 'rewards/reward_fn/mean': '0.368', 'rewards/reward_fn/std': '0.1599', 'reward': '0.368', 'reward_std': '0.1213', 'frac_reward_zero_std': '0.6', 'completion_length': '91.65', 'kl': '0.008677', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.25'}
# {'loss': '0.008952', 'grad_norm': '0.00388', 'learning_rate': '4.75e-06', 'num_tokens': '5.436e+04', 'completions/mean_length': '81.58', 'completions/min_length': '48.4', 'completions/max_length': '134.2', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '78.75', 'completions/min_terminated_length': '48.4', 'completions/max_terminated_length': '118', 'rewards/reward_fn/mean': '0.2363', 'rewards/reward_fn/std': '0.1915', 'reward': '0.2363', 'reward_std': '0.1773', 'frac_reward_zero_std': '0.3', 'completion_length': '80.6', 'kl': '0.009117', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.3'}
# {'loss': '-0.03092', 'grad_norm': '0.8457', 'learning_rate': '4.611e-06', 'num_tokens': '6.321e+04', 'completions/mean_length': '85.9', 'completions/min_length': '55', 'completions/max_length': '142.6', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '85.9', 'completions/min_terminated_length': '55', 'completions/max_terminated_length': '142.6', 'rewards/reward_fn/mean': '0.3427', 'rewards/reward_fn/std': '0.2299', 'reward': '0.3427', 'reward_std': '0.1655', 'frac_reward_zero_std': '0.5', 'completion_length': '84.9', 'kl': '0.01151', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.35'}
# {'loss': '-0.002664', 'grad_norm': '1.179', 'learning_rate': '4.472e-06', 'num_tokens': '7.201e+04', 'completions/mean_length': '83.88', 'completions/min_length': '49.2', 'completions/max_length': '163.8', 'completions/clipped_ratio': '0.075', 'completions/mean_terminated_length': '74.48', 'completions/min_terminated_length': '49.2', 'completions/max_terminated_length': '114', 'rewards/reward_fn/mean': '0.3268', 'rewards/reward_fn/std': '0.1688', 'reward': '0.3268', 'reward_std': '0.137', 'frac_reward_zero_std': '0.4', 'completion_length': '82.95', 'kl': '0.01247', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.4'}
# {'loss': '0.0425', 'grad_norm': '0.9769', 'learning_rate': '4.333e-06', 'num_tokens': '8.103e+04', 'completions/mean_length': '89.05', 'completions/min_length': '53', 'completions/max_length': '153.4', 'completions/clipped_ratio': '0.05', 'completions/mean_terminated_length': '83.11', 'completions/min_terminated_length': '53', 'completions/max_terminated_length': '119.6', 'rewards/reward_fn/mean': '0.3517', 'rewards/reward_fn/std': '0.1357', 'reward': '0.3517', 'reward_std': '0.1065', 'frac_reward_zero_std': '0.6', 'completion_length': '88.1', 'kl': '0.005652', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.45'}
#
# 🚀 STEP 50: THE AGENT IS THINKING...
#
# {"action_type": "escalate", "value": "escalate to customer service", "reasoning": "Customer has requested immediate refund after applying an invalid discount code.", "why": "The ticket indicates that the customer ignored previous instructions for applying the correct code without further verification of its validity, leading to this action."}
# {'loss': '0.02221', 'grad_norm': '0.8195', 'learning_rate': '4.194e-06', 'num_tokens': '8.985e+04', 'completions/mean_length': '83.12', 'completions/min_length': '53', 'completions/max_length': '130.8', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '83.12', 'completions/min_terminated_length': '53', 'completions/max_terminated_length': '130.8', 'rewards/reward_fn/mean': '0.3192', 'rewards/reward_fn/std': '0.225', 'reward': '0.3192', 'reward_std': '0.1633', 'frac_reward_zero_std': '0.4', 'completion_length': '82.12', 'kl': '0.01216', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.5'}
# {'loss': '0.0278', 'grad_norm': '1.013', 'learning_rate': '4.056e-06', 'num_tokens': '9.861e+04', 'completions/mean_length': '82.08', 'completions/min_length': '49.8', 'completions/max_length': '142.6', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '79.01', 'completions/min_terminated_length': '49.8', 'completions/max_terminated_length': '123.2', 'rewards/reward_fn/mean': '0.15', 'rewards/reward_fn/std': '0.3402', 'reward': '0.15', 'reward_std': '0.1691', 'frac_reward_zero_std': '0.4', 'completion_length': '81.1', 'kl': '0.01956', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.55'}
# {'loss': '0.03601', 'grad_norm': '0.8354', 'learning_rate': '3.917e-06', 'num_tokens': '1.076e+05', 'completions/mean_length': '87.72', 'completions/min_length': '54.4', 'completions/max_length': '139.2', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '84.82', 'completions/min_terminated_length': '54.4', 'completions/max_terminated_length': '123.2', 'rewards/reward_fn/mean': '0.3307', 'rewards/reward_fn/std': '0.1665', 'reward': '0.3307', 'reward_std': '0.1485', 'frac_reward_zero_std': '0.6', 'completion_length': '86.75', 'kl': '0.01102', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.6'}
# {'loss': '0.04225', 'grad_norm': '0.001664', 'learning_rate': '3.778e-06', 'num_tokens': '1.163e+05', 'completions/mean_length': '80.45', 'completions/min_length': '51.8', 'completions/max_length': '140.6', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '77.22', 'completions/min_terminated_length': '51.8', 'completions/max_terminated_length': '123.8', 'rewards/reward_fn/mean': '0.08325', 'rewards/reward_fn/std': '0.2309', 'reward': '0.08325', 'reward_std': '0.09588', 'frac_reward_zero_std': '0.8', 'completion_length': '79.47', 'kl': '0.0183', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.65'}
# {'loss': '0.008499', 'grad_norm': '0.002174', 'learning_rate': '3.639e-06', 'num_tokens': '1.25e+05', 'completions/mean_length': '82.35', 'completions/min_length': '52.2', 'completions/max_length': '131.6', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '82.35', 'completions/min_terminated_length': '52.2', 'completions/max_terminated_length': '131.6', 'rewards/reward_fn/mean': '0.235', 'rewards/reward_fn/std': '0.2058', 'reward': '0.235', 'reward_std': '0.04842', 'frac_reward_zero_std': '0.8', 'completion_length': '81.35', 'kl': '0.0126', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.7'}
# {'loss': '0.04791', 'grad_norm': '0.8967', 'learning_rate': '3.5e-06', 'num_tokens': '1.339e+05', 'completions/mean_length': '84.42', 'completions/min_length': '51.8', 'completions/max_length': '140.2', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '81.74', 'completions/min_terminated_length': '51.8', 'completions/max_terminated_length': '137.2', 'rewards/reward_fn/mean': '0.3252', 'rewards/reward_fn/std': '0.1937', 'reward': '0.3252', 'reward_std': '0.1596', 'frac_reward_zero_std': '0.4', 'completion_length': '83.45', 'kl': '0.01869', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.75'}
# {'loss': '0.02166', 'grad_norm': '1.002', 'learning_rate': '3.361e-06', 'num_tokens': '1.426e+05', 'completions/mean_length': '81.92', 'completions/min_length': '50.8', 'completions/max_length': '141.4', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '78.57', 'completions/min_terminated_length': '50.8', 'completions/max_terminated_length': '123', 'rewards/reward_fn/mean': '0.3282', 'rewards/reward_fn/std': '0.1592', 'reward': '0.3282', 'reward_std': '0.1057', 'frac_reward_zero_std': '0.7', 'completion_length': '80.95', 'kl': '0.02402', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.8'}
# {'loss': '0.02695', 'grad_norm': '0.0008885', 'learning_rate': '3.222e-06', 'num_tokens': '1.515e+05', 'completions/mean_length': '84.17', 'completions/min_length': '47.6', 'completions/max_length': '148.2', 'completions/clipped_ratio': '0.05', 'completions/mean_terminated_length': '78.41', 'completions/min_terminated_length': '47.6', 'completions/max_terminated_length': '115.2', 'rewards/reward_fn/mean': '0.1907', 'rewards/reward_fn/std': '0.3058', 'reward': '0.1907', 'reward_std': '0.1085', 'frac_reward_zero_std': '0.6', 'completion_length': '83.22', 'kl': '0.01581', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.85'}
# {'loss': '0.01599', 'grad_norm': '0.7307', 'learning_rate': '3.083e-06', 'num_tokens': '1.603e+05', 'completions/mean_length': '80.12', 'completions/min_length': '49.2', 'completions/max_length': '113.6', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '80.12', 'completions/min_terminated_length': '49.2', 'completions/max_terminated_length': '113.6', 'rewards/reward_fn/mean': '0.1305', 'rewards/reward_fn/std': '0.2185', 'reward': '0.1305', 'reward_std': '0.139', 'frac_reward_zero_std': '0.7', 'completion_length': '79.12', 'kl': '0.01455', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.9'}
# {'loss': '0.01742', 'grad_norm': '0.0006315', 'learning_rate': '2.944e-06', 'num_tokens': '1.691e+05', 'completions/mean_length': '79.47', 'completions/min_length': '50.2', 'completions/max_length': '117.6', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '79.47', 'completions/min_terminated_length': '50.2', 'completions/max_terminated_length': '117.6', 'rewards/reward_fn/mean': '0.2077', 'rewards/reward_fn/std': '0.234', 'reward': '0.2077', 'reward_std': '0.0445', 'frac_reward_zero_std': '0.9', 'completion_length': '78.47', 'kl': '0.0186', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.95'}
#
# 🚀 STEP 100: THE AGENT IS THINKING...
#
# {"action_type": "escalate", "value": "Refuse to resolve this issue due to low sentiment.", "reasoning": "The customer's experience has been negative with multiple issues including an incorrect discount code not being applied correctly during checkout. The current escalation strategy focuses on resolving their specific concern rather than addressing the full SLA of our system."}
# {'loss': '0.04002', 'grad_norm': '0.0005905', 'learning_rate': '2.806e-06', 'num_tokens': '1.776e+05', 'completions/mean_length': '76.25', 'completions/min_length': '49.4', 'completions/max_length': '122.2', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '73.21', 'completions/min_terminated_length': '49.4', 'completions/max_terminated_length': '110.8', 'rewards/reward_fn/mean': '0.2782', 'rewards/reward_fn/std': '0.1754', 'reward': '0.2782', 'reward_std': '0.06353', 'frac_reward_zero_std': '0.8', 'completion_length': '75.28', 'kl': '0.01707', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1'}
# {'loss': '0.02802', 'grad_norm': '1.083', 'learning_rate': '2.667e-06', 'num_tokens': '1.862e+05', 'completions/mean_length': '78.97', 'completions/min_length': '49.8', 'completions/max_length': '128.8', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '75.79', 'completions/min_terminated_length': '49.8', 'completions/max_terminated_length': '107.8', 'rewards/reward_fn/mean': '0.3364', 'rewards/reward_fn/std': '0.1515', 'reward': '0.3364', 'reward_std': '0.1071', 'frac_reward_zero_std': '0.7', 'completion_length': '78', 'kl': '0.04802', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.05'}
# {'loss': '0.02087', 'grad_norm': '0.0007494', 'learning_rate': '2.528e-06', 'num_tokens': '1.949e+05', 'completions/mean_length': '79.55', 'completions/min_length': '44.8', 'completions/max_length': '123.8', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '79.55', 'completions/min_terminated_length': '44.8', 'completions/max_terminated_length': '123.8', 'rewards/reward_fn/mean': '0.1255', 'rewards/reward_fn/std': '0.225', 'reward': '0.1255', 'reward_std': '0.1803', 'frac_reward_zero_std': '0.6', 'completion_length': '78.55', 'kl': '0.04105', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.1'}
# {'loss': '0.01346', 'grad_norm': '0.000725', 'learning_rate': '2.389e-06', 'num_tokens': '2.037e+05', 'completions/mean_length': '82.62', 'completions/min_length': '46.4', 'completions/max_length': '128.4', 'completions/clipped_ratio': '0.05', 'completions/mean_terminated_length': '76.73', 'completions/min_terminated_length': '46.4', 'completions/max_terminated_length': '109.4', 'rewards/reward_fn/mean': '0.2647', 'rewards/reward_fn/std': '0.1255', 'reward': '0.2647', 'reward_std': '0.09053', 'frac_reward_zero_std': '0.6', 'completion_length': '81.67', 'kl': '0.02226', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.15'}
# {'loss': '0.03523', 'grad_norm': '1.116', 'learning_rate': '2.25e-06', 'num_tokens': '2.123e+05', 'completions/mean_length': '77.88', 'completions/min_length': '46.8', 'completions/max_length': '134.4', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '74.86', 'completions/min_terminated_length': '46.8', 'completions/max_terminated_length': '120.6', 'rewards/reward_fn/mean': '0.2582', 'rewards/reward_fn/std': '0.192', 'reward': '0.2582', 'reward_std': '0.1233', 'frac_reward_zero_std': '0.5', 'completion_length': '76.9', 'kl': '0.04931', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.2'}
# {'loss': '0.002269', 'grad_norm': '0.0007539', 'learning_rate': '2.111e-06', 'num_tokens': '2.207e+05', 'completions/mean_length': '74.42', 'completions/min_length': '51.4', 'completions/max_length': '113.6', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '74.42', 'completions/min_terminated_length': '51.4', 'completions/max_terminated_length': '113.6', 'rewards/reward_fn/mean': '0.381', 'rewards/reward_fn/std': '0.01728', 'reward': '0.381', 'reward_std': '0.01094', 'frac_reward_zero_std': '0.9', 'completion_length': '73.42', 'kl': '0.05523', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.25'}
# {'loss': '0.01806', 'grad_norm': '0.001249', 'learning_rate': '1.972e-06', 'num_tokens': '2.29e+05', 'completions/mean_length': '71.17', 'completions/min_length': '49.2', 'completions/max_length': '109.2', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '71.17', 'completions/min_terminated_length': '49.2', 'completions/max_terminated_length': '109.2', 'rewards/reward_fn/mean': '0.2015', 'rewards/reward_fn/std': '0.2455', 'reward': '0.2015', 'reward_std': '0.05169', 'frac_reward_zero_std': '0.8', 'completion_length': '70.17', 'kl': '0.02201', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.3'}
# {'loss': '2.434e-05', 'grad_norm': '0.001984', 'learning_rate': '1.833e-06', 'num_tokens': '2.371e+05', 'completions/mean_length': '66.17', 'completions/min_length': '42.8', 'completions/max_length': '109.4', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '66.17', 'completions/min_terminated_length': '42.8', 'completions/max_terminated_length': '109.4', 'rewards/reward_fn/mean': '0.39', 'rewards/reward_fn/std': '0', 'reward': '0.39', 'reward_std': '0', 'frac_reward_zero_std': '1', 'completion_length': '65.17', 'kl': '0.02509', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.35'}
# {'loss': '0.01492', 'grad_norm': '0.000952', 'learning_rate': '1.694e-06', 'num_tokens': '2.454e+05', 'completions/mean_length': '71.2', 'completions/min_length': '44.2', 'completions/max_length': '113.6', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '71.2', 'completions/min_terminated_length': '44.2', 'completions/max_terminated_length': '113.6', 'rewards/reward_fn/mean': '0.1142', 'rewards/reward_fn/std': '0.3539', 'reward': '0.1142', 'reward_std': '0.0715', 'frac_reward_zero_std': '0.7', 'completion_length': '70.2', 'kl': '0.0483', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.4'}
# {'loss': '0.03125', 'grad_norm': '0.0009513', 'learning_rate': '1.556e-06', 'num_tokens': '2.54e+05', 'completions/mean_length': '76.85', 'completions/min_length': '53.8', 'completions/max_length': '131.4', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '73.51', 'completions/min_terminated_length': '53.8', 'completions/max_terminated_length': '108.4', 'rewards/reward_fn/mean': '0.2825', 'rewards/reward_fn/std': '0.1481', 'reward': '0.2825', 'reward_std': '0.05509', 'frac_reward_zero_std': '0.8', 'completion_length': '75.88', 'kl': '0.025', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.45'}
#
# 🚀 STEP 150: THE AGENT IS THINKING...
#
# {"action_type": "escalate", "value": "Escalation to Senior Support Specialist", "reasoning": "Customer has escalated their issue to senior support due to the complexity of applying a discount code at checkout without proper verification and processing."}
# {'loss': '-0.01583', 'grad_norm': '0.002301', 'learning_rate': '1.417e-06', 'num_tokens': '2.625e+05', 'completions/mean_length': '75.1', 'completions/min_length': '48.8', 'completions/max_length': '114.4', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '75.1', 'completions/min_terminated_length': '48.8', 'completions/max_terminated_length': '114.4', 'rewards/reward_fn/mean': '0.32', 'rewards/reward_fn/std': '0.104', 'reward': '0.32', 'reward_std': '0.01155', 'frac_reward_zero_std': '0.9', 'completion_length': '74.1', 'kl': '0.03791', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.5'}
# {'loss': '0.01224', 'grad_norm': '0.0008524', 'learning_rate': '1.278e-06', 'num_tokens': '2.71e+05', 'completions/mean_length': '76.08', 'completions/min_length': '49.4', 'completions/max_length': '130.2', 'completions/clipped_ratio': '0.05', 'completions/mean_terminated_length': '69.29', 'completions/min_terminated_length': '49.4', 'completions/max_terminated_length': '104.4', 'rewards/reward_fn/mean': '0.2432', 'rewards/reward_fn/std': '0.2749', 'reward': '0.2432', 'reward_std': '0.1409', 'frac_reward_zero_std': '0.6', 'completion_length': '75.12', 'kl': '0.03762', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.55'}
# {'loss': '0.04284', 'grad_norm': '0.0005428', 'learning_rate': '1.139e-06', 'num_tokens': '2.796e+05', 'completions/mean_length': '77.4', 'completions/min_length': '51.4', 'completions/max_length': '138', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '74.02', 'completions/min_terminated_length': '51.4', 'completions/max_terminated_length': '112.8', 'rewards/reward_fn/mean': '0.3217', 'rewards/reward_fn/std': '0.1624', 'reward': '0.3217', 'reward_std': '0.1365', 'frac_reward_zero_std': '0.6', 'completion_length': '76.42', 'kl': '0.0302', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '1.6'}

# %% [markdown]
# ## 5. Reward Curves
#
# If `ENABLE_FRONTIER=True`, an additional frontier curve will be appended automatically.

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

fig = plt.figure(figsize=(15, 5))
fig.suptitle('FrontierOps Arena — GRPO Training Reward Curves', fontsize=14, fontweight='bold')

colors = {'easy': '#22c55e', 'medium': '#f59e0b', 'hard': '#ef4444'}

for i, log in enumerate(training_log):
    ax = fig.add_subplot(1, 3, i+1)
    rewards = [e.get('reward', e.get('train_reward', 0)) for e in log['log_history'] if 'reward' in e or 'train_reward' in e]
    steps = list(range(len(rewards)))
    ax.plot(steps, rewards, color=colors[log['task']], linewidth=2)
    ax.fill_between(steps, rewards, alpha=0.15, color=colors[log['task']])
    ax.set_title(f"{log['task'].capitalize()} Task", fontweight='bold')
    ax.set_xlabel('Training Steps')
    ax.set_ylabel('Reward')
    ax.grid(True, alpha=0.3)
    ax.set_facecolor('#0a0f1e')
    fig.patch.set_facecolor('#111827')
    ax.tick_params(colors='white')
    ax.title.set_color('white')
    ax.xaxis.label.set_color('white')
    ax.yaxis.label.set_color('white')
    for spine in ax.spines.values(): spine.set_edgecolor('#334155')

plt.tight_layout()
plt.savefig('reward_curves.png', dpi=150, bbox_inches='tight', facecolor='#111827')
plt.show()
print('Saved: reward_curves.png')

# %% [markdown]
# ## 6. Before vs After Evaluation
#
# This section keeps the original core comparison (`easy`, `medium`, `hard`) for continuity with earlier artifacts. Use `evaluate_models.py --offline --tasks easy,medium,hard,frontier ...` for the current full scorecard pipeline.

# %%
# Compare random baseline vs trained model with real measurements

def evaluate_trained_model(task_level: str, n_episodes: int = 20):
    env = CustomerSupportEnv(task_level=task_level)
    episode_rewards = []

    for _ in range(n_episodes):
        obs = env.reset()
        total_reward = 0.0
        max_steps = env.task_config['max_steps']
        step = 0

        while not env.done and step < max_steps:
            step += 1
            messages = [
                {'role': 'system', 'content': SYSTEM_PROMPTS[task_level]},
                {'role': 'user', 'content': (
                    f"Ticket: {obs.current_ticket.description}\n"
                    f"Sentiment: {obs.current_ticket.sentiment:.2f}\n"
                    f"SLA: {obs.current_sla_status}\n"
                    f"VIP: {obs.current_ticket.is_vip}\n"
                    f"Previous Contacts: {obs.current_ticket.previous_contacts}"
                )}
            ]

            inputs = tokenizer.apply_chat_template(
                messages,
                return_tensors='pt',
                add_generation_prompt=True
            ).to(model.device)

            with torch.no_grad():
                outputs = model.generate(
                    inputs,
                    max_new_tokens=120,
                    temperature=0.2,
                    do_sample=True,
                    pad_token_id=tokenizer.eos_token_id,
                )

            text = tokenizer.decode(outputs[0][inputs.shape[1]:], skip_special_tokens=True)
            try:
                s, e = text.find('{'), text.rfind('}') + 1
                data = json.loads(text[s:e]) if s != -1 and e > s else {}
            except Exception:
                data = {}

            action = Action(
                action_type=str(data.get('action_type', 'request_info')),
                value=str(data.get('value', '')),
                reasoning=str(data.get('reasoning', '')),
            )
            obs, reward, _, _ = env.step(action)
            total_reward += reward

        episode_rewards.append(total_reward)

    return episode_rewards

print('Running trained-model evaluation...')
trained_easy   = evaluate_trained_model('easy', 20)
trained_medium = evaluate_trained_model('medium', 20)
trained_hard   = evaluate_trained_model('hard', 20)

results = {
    'before': {
        'easy':   sum(baseline_easy)/len(baseline_easy),
        'medium': sum(baseline_medium)/len(baseline_medium),
        'hard':   sum(baseline_hard)/len(baseline_hard),
    },
    'after': {
        'easy':   sum(trained_easy)/len(trained_easy),
        'medium': sum(trained_medium)/len(trained_medium),
        'hard':   sum(trained_hard)/len(trained_hard),
    }
}

print('=== Before vs After ===')
print(f'{"Task":<10} {"Before":>10} {"After":>10} {"Improvement":>12}')
print('-' * 45)
for task in ['easy', 'medium', 'hard']:
    before = results['before'][task]
    after  = results['after'][task]
    delta  = ((after - before) / abs(before)) * 100 if before != 0 else 0
    print(f'{task:<10} {before:>10.4f} {after:>10.4f} {delta:>+11.1f}%')

os.makedirs('results', exist_ok=True)
with open('results/baseline_vs_trained_colab.json', 'w') as f:
    json.dump(results, f, indent=2)
print('Saved: results/baseline_vs_trained_colab.json')

# %% [markdown]
# ## 7. Push to HuggingFace Hub
#
# Upload the trained model and reward curves to HuggingFace.
#
# ### Optional: Generate latest offline benchmark pack from Colab runtime
#
# ```bash
# python evaluate_models.py --offline --tasks easy,medium,hard,frontier --episodes 3 --seeds 41,42,43 --output results/final_baseline_vs_trained.md --trained-model offline_stub
# python ablation_eval.py
# ```
#
# This produces the same judge-facing artifacts used in the repository (`results/final_*`, `results/ablation_hack_penalty.json`).

# %%
from huggingface_hub import login
login()  # enter your HF token

REPO_ID = 'punith2001/frontierops-arena-model'
model.push_to_hub(REPO_ID)
tokenizer.push_to_hub(REPO_ID)
print(f'Model pushed to: https://huggingface.co/{REPO_ID}')
